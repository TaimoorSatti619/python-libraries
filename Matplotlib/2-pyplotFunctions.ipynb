# %%
import matplotlib.pyplot as plt


#plt.plt(x,y, color="colorname",linestyle="line style",linewidth="value",marker="marker symbol",label="label name")

# plt.xlabel('text')
# plt.ylabel('text')

#plt.title('Title of the graph')

# plt.legend()  parameters optional  => loc='upper left' ,fontsize=12

# plt.grid() parameters optional  => color= 'gray',linestyle=':', linewidth=1

#plt.xlim(start,end)
#plt.ylim(start,end)

# plt.xticks([actual data],[change wala data])
# plt.yticks([actual data],[change wala data])

# plt.show()   for displying graph

months = [1,2,3,4]
sales = [1000,1500,1200,1800]

plt.plot(months,sales, color='blue',linestyle='--',linewidth = 2, marker='o',label='2025 Sales data')
plt.xlabel('Months')
plt.ylabel('Sales per Month')
plt.title('Monthly Sales Data report')
plt.legend(loc='upper left',fontsize=12)
plt.grid(color= 'gray',linestyle=':', linewidth=1)
plt.xlim(1,4)
plt.xticks([1,2,3,4],['M1','M2','M3','M4'])
plt.ylim(0,2000)


plt.show()
