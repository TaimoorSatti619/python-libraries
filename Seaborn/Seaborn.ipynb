# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins["species"].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins["island"].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %% [markdown]
# # **Scatter plot**

# %%
sns.scatterplot(data = penguins, x = "flipper_length_mm",y = "body_mass_g",hue = "sex")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
 # The ways of styling themes are as :
 # white
 # dark
 # whitegrid
 # darkgrid
 # ticks

# set_context()    alows us to override default parameters

# %%
sns.set_style("ticks")
sns.set_context("notebook")
sns.scatterplot(data = penguins, x = "flipper_length_mm",y = "body_mass_g",hue = "island",palette="Dark2")
sns.despine()

# %%
sns.scatterplot(data = penguins,x = "species",y = "body_mass_g",hue = "island",style="sex",alpha=0.5)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.stripplot(data = penguins,x = "species",y = "body_mass_g",hue = "island",dodge = True,jitter = True)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# # **Swarm plot**

# %%
sns.set_context("talk")
sns.swarmplot(data = penguins,x="species",y = "body_mass_g",hue = "island")
sns.despine()

# %% [markdown]
# # **Histogram**

# %%
sns.set_context("notebook")
sns.histplot(data = penguins,x = "body_mass_g",hue = "sex",multiple="stack")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# # **Regression plot**

# %%
sns.regplot(data = penguins,x = "body_mass_g",y = "flipper_length_mm",color = "green")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# # **Line plot**

# %%
sns.set_style("whitegrid")
sns.lineplot(data = penguins,x = "body_mass_g",y = "flipper_length_mm",hue = "island",style = "sex")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# # **Joint plots**

# %%
sns.jointplot(data = penguins,x = "body_mass_g",y = "flipper_length_mm")

# %%
sns.jointplot(data = penguins,x = "body_mass_g",y = "flipper_length_mm",hue="sex",kind = "kde")

# %% [markdown]
# # **Bar plot**

# %%
sns.barplot(data = penguins,x = "species",y = "body_mass_g",hue = "sex",palette=["pink","skyblue"],estimator=np.var)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# # **Count plot**

# %%
sns.countplot(data = penguins,x = "species",hue = "island",palette="Set2")
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# # **Box Plot**

# %%
sns.boxplot(data = penguins,x = "species",y = "body_mass_g",hue = "sex")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# # **Voilen plot**

# %%
sns.violinplot(data = penguins,x = "species",y = "body_mass_g",hue = "sex",split=True)

# width of the voilen : Density of the data at differnet values
# middle line : median
# Thick bar : Interquartile range (if inner= 'box')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.violinplot(data = penguins,x = "species",y = "body_mass_g",palette="pastel")
sns.swarmplot(data = penguins,x = "species",y = "body_mass_g",hue="island",size = 3,palette="dark")
# Out:
# /tmp/ipython-input-974272638.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data = penguins,x = "species",y = "body_mass_g",palette="pastel")
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# # **Kde plot**

# %%
sns.kdeplot(data = penguins,x = "body_mass_g",hue = "species",fill = True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# # **Heat map**

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
coloumns = ["body_mass_g","flipper_length_mm","bill_length_mm","bill_depth_mm"]
corr = penguins[coloumns].corr()
corr
# Out:
#                    body_mass_g  flipper_length_mm  bill_length_mm  \
# body_mass_g           1.000000           0.871202        0.595110
# flipper_length_mm     0.871202           1.000000        0.656181
# bill_length_mm        0.595110           0.656181        1.000000
# bill_depth_mm        -0.471916          -0.583851       -0.235053
#
#                    bill_depth_mm
# body_mass_g            -0.471916
# flipper_length_mm      -0.583851
# bill_length_mm         -0.235053
# bill_depth_mm           1.000000

# %%
sns.heatmap(data=penguins[coloumns].corr(),annot=True,cmap="Blues",vmin= -0.2,linewidth="2",linecolor="black")
# Out:
# <Axes: >

# %% [markdown]
# # **Rug plot**

# %%
sns.rugplot(data=penguins,y="body_mass_g",hue="species",palette="Set2",height=0.2)
# Out:
# <Axes: ylabel='body_mass_g'>

# %% [markdown]
# # **Pair plot**

# %%
sns.pairplot(data=penguins,hue= "sex",palette="Set2",diag_kind="hist")

# %% [markdown]
# # **Pair Grid**

# %%
# pair grid ->  subplot grid for plotting pairwise relationships in a dataset

graph = sns.PairGrid(data=penguins,hue="sex",palette="Set2")
graph.map_upper(sns.scatterplot)
graph.map_lower(sns.kdeplot)
graph.map_diag(sns.histplot)
graph.add_legend()
