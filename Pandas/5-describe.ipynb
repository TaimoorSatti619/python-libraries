# %%
import pandas as pd

# %%
data = {
    "Name" : ['Ali','Ahmed','Hamza','Wasi','Zakir','Ahad','John','Kashif'],
    "Age" : [20,21,23,24,22,25,26,28],
    "Salary" :[50000,60000,70000,80000,52000,53000,55000,58000,],
    "Performance Score" : [85,90,87,86,80,92,91,93]
}

df = pd.DataFrame(data)
print("Sample Data")
print(df)
# Out:
# Sample Data
#      Name  Age  Salary  Performance Score
# 0     Ali   20   50000                 85
# 1   Ahmed   21   60000                 90
# 2   Hamza   23   70000                 87
# 3    Wasi   24   80000                 86
# 4   Zakir   22   52000                 80
# 5    Ahad   25   53000                 92
# 6    John   26   55000                 91
# 7  Kashif   28   58000                 93

# %%
print(df.describe())
# Out:
#             Age        Salary  Performance Score
# count   8.00000      8.000000           8.000000
# mean   23.62500  59750.000000          88.000000
# std     2.66927  10292.160678           4.342481
# min    20.00000  50000.000000          80.000000
# 25%    21.75000  52750.000000          85.750000
# 50%    23.50000  56500.000000          88.500000
# 75%    25.25000  62500.000000          91.250000
# max    28.00000  80000.000000          93.000000
