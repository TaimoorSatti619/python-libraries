# %%
import pandas as pd

# %%
"""
vertically (row-wise)
horizontally (colun-wise)

pd.concat([df1,df2],axis=0,ignore_index=True)

axis = 0   row-wise
axis = 1    column-wise
"""
# Out:
# '\nvertically (row-wise)\nhorizontally (colun-wise)\n\npd.concat([df1,df2],axis=0,ignore_index=True)\n\naxis = 0   row-wise\naxis = 1    column-wise\n'

# %%
df_customers = pd.DataFrame({
    'CustomerId':[1,2,3],
    'Name':['Ali','Hamza','Ahmed']
})

df_orders = pd.DataFrame({
    'CustomerId':[4,5,6],
    'Name':['Wasi','Zakir','Faris']
})

# %%
# Vertically Merged
df_concat = pd.concat([df_customers,df_orders],axis=0,ignore_index=True)
print(df_concat)
# Out:
#    CustomerId   Name
# 0           1    Ali
# 1           2  Hamza
# 2           3  Ahmed
# 3           4   Wasi
# 4           5  Zakir
# 5           6  Faris

# %%
# Horizontaly Merged
df_concat = pd.concat([df_customers,df_orders],axis=1,ignore_index=True)
print(df_concat)
# Out:
#    0      1  2      3
# 0  1    Ali  4   Wasi
# 1  2  Hamza  5  Zakir
# 2  3  Ahmed  6  Faris
